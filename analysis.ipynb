# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('./logs/df_results.csv')
results_best = pd.read_csv('../src_new_V58/logs/df_results.csv')

# %%
len(results)
# Out:
# 147

# %%
idx_val = results['valid_score'].values.argmax()
print(idx_val + 1)
idx_dev = results['dev_score'].values.argmax()
print(idx_dev + 1)
print('valid', results['valid_score'][idx_val])
print('dev', results['dev_score'][idx_dev])
# Out:
# 137
# 134
# valid 0.9932226799101552
# dev 0.9922569691834681

# %%
results['train_score'].plot()
results['valid_score'].plot()
results['dev_score'].plot()
plt.ylim(0.90, 1.0)
# Out:
# (0.9, 1.0)

# %%
results['train_loss'].plot()
results['valid_loss'].plot()
results['dev_loss'].plot()
# plt.ylim(0.90, 1.0)

# %%
#results['train_score'].plot()
results['valid_score'].plot()
results['dev_score'].plot()

# results_best['train_score'].plot()
results_best['valid_score'].plot()
results_best['dev_score'].plot()
plt.ylim(0.98, 1)
# Out:
# (0.98, 1)
